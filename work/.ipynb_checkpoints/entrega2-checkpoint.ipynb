# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Oct 21 13:25:40 2020

@author: pablo
"""

import os

from MRE import Job

inputDir = "datasets/website/"
outputDir = "output/website"

# %%
# <id_user, id_page, time>
# La página más visitada (la página en la que más tiempo permaneció) para cada usuario

def fmapA(key, value, context):
    values = value.split()
    context.write((key, values[0]), values[1])

def fredA(key, values, context):
    total = 0
    for v in values:
        total += int(v)
    context.write(key, total)

os.makedirs(outputDir + '/a/1', exist_ok=True)
jobA = Job(inputDir, outputDir + '/a/1', fmapA, fredA)
jobA.setCombiner(fredA)
success = jobA.waitForCompletion()
# <id_user, id_page, time>
def fmapA2(key, value, context):
    values = value.split()
    context.write(key, values)

def fcombA2(key, values, context):
    max= (0,0)
    for v in values:
        if (int(max[0]) < int(v[0]) ):
            max = v
    context.write(key, max)

# <id_user, time, id_page>
def fShuffleA2(key1, key2):
    if(key1[0] == key2[0]):
        return 0
    elif(key1[0] < key2[0]):
        return -1
    else:
        return 1

def fSortA2(aKey, anotherKey):
    if(aKey[1] == anotherKey[1]):
        return 0
    elif(aKey[1]  < anotherKey[1]):
        return -1
    else:
        return 1



def fredA2(key, values, context):
    max= (0,0)
    for v in values:
        if (int(max[1]) < int(v[1]) ):
            max = v
    context.write(key, max)


os.makedirs(outputDir + '/a/2', exist_ok=True)
jobA2 = Job(outputDir + '/a/1', outputDir + '/a/2', fmapA2, fredA2)
#jobA2.setCombiner(fcombA)
#jobA2.setShuffleCmp(fShuffleA2)
#jobA2.setSortCmp(fSortA2)
success = jobA2.waitForCompletion()

# %%
# El usuario que más páginas distintas visitó

# calculo la canitdad de paginas visitadas por usuario agrupadas por página
def fmapB(key, value, context):
    values = value.split()
    context.write((key,values[0]), 1)

def fcombB(key, values, context):
    total = 0
    for v in values:
        total += 1
    context.write(key,total)

def cmpShuffle(key1, key2):
    if(key1[1] == key2[1]):
        return 0
    elif(key1[1] < key2[1]):
        return -1
    else:
        return 1

def fSortCmpB(aKey, anotherKey):
    if(aKey == anotherKey):
        return 0
    elif(aKey < anotherKey):
        return -1
    else:
        return 1
   
def fredB(key, values, context):
    total = 0
    for v in values:
        total += v
    context.write(key,total)

os.makedirs(outputDir + '/b/1', exist_ok=True)
jobB = Job(inputDir, outputDir + '/b/1', fmapB, fredB)
jobB.setCombiner(fcombB)
success = jobB.waitForCompletion()

# calculo cantidad de páginas distintas visitados por usuario
def fmapB2(key, value, context):
    context.write(key, 1)

def fcombB2(key, values, context):
    total = 0
    for v in values:
        total += 1
    context.write(key,total)

def fredB2(key, values, context):
    total = 0
    for v in values:
        total += v
    context.write(key,total)

os.makedirs(outputDir + '/b/2', exist_ok=True)
jobB2 = Job(outputDir + '/b/1', outputDir + '/b/2', fmapB2, fredB2)
jobB2.setCombiner(fcombB2)
#jobB2.setSortCmp(fSortCmpB2)
success = jobB2.waitForCompletion()

# %%
# La página más visitada (en cuanto a cantidad de visitas, sin importar el tiempo
# de permanencia) por todos los usuarios.

# <id_user, time, id_page>
def fmapC(key, value, context):
    values = value.split()
    context.write(values[1], 1)

def fredC(key, values, context):
    total = 0
    for v in values:
        total += v
    context.write(key,total)

os.makedirs(outputDir + '/c/1', exist_ok=True)
jobC = Job(inputDir, outputDir + '/c/1', fmapC, fredC)
jobC.setCombiner(fredC)
success = jobC.waitForCompletion()

# <id_page, total>
def fmapC2(key, value, context):
    value = value.split()
    context.write(1, (key, value[0]))

def fredC2(key, values, context):
    max = (0,0)
    for v in values:
        if (int(max[1]) < int(v[1]) ):
            max = v
    context.write(max[0],max[1])

os.makedirs(outputDir + '/c/2', exist_ok=True)
jobC2 = Job(outputDir + '/c/1', outputDir + '/c/2', fmapC2, fredC2)
success = jobC2.waitForCompletion()
